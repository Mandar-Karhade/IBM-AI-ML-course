# %% [markdown]
# ### Downloading Data
#
# To download the data, we will use !wget to download it from IBM Object Storage.

# %%
# Download this file 
#!wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-Coursera/labs/Data_files/FuelConsumptionCo2.csv"

# %% [markdown]
# <h2 id="reading_data">Reading the data in adnd Data exploration </h2>

# %%
import os 
os.chdir("C:\\Users\\manka\\Documents\\GitHub\\Machine-learning-quickbook")
df = pd.read_csv("FuelConsumptionCo2.csv")

# %% [markdown]
# <h2 id="exploratory_analysis">Exploratory data analysis </h2>

# %%
from pandas_profiling import ProfileReport
# profile = ProfileReport(df)
# profile.to_widgets()

# %% [markdown]
# Lets select some features to explore more.

# %% [markdown]
# we can plot each of these features:

# %% [markdown]
# <h2 id="simple_regression">Simple Regression Model</h2>
# Linear Regression fits a linear model with coefficients $\theta = (\theta_1, ..., \theta_n)$ to minimize the 'residual sum of squares' between the independent x in the dataset, and the dependent y by the linear approximation.

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline
import os, seaborn as sns

# Get data
os.chdir("C:\\Users\\manka\\Documents\\GitHub\\Machine-learning-quickbook")
df = pd.read_csv("FuelConsumptionCo2.csv")
# df.hist()

# Describe independent and dependent variables
ind = ['ENGINESIZE']
dep = ['CO2EMISSIONS']


# Train test split with proportion split
msk = np.random.rand(len(df)) < 0.8
X, Y = df[ind], df[dep]
# display(X.head)
# display(Y.head)

# plot distributions 
display(sns.pairplot(df[ind+dep]))
plt.show()

# train test split
train_x, test_x, train_y, test_y = np.asanyarray(X[msk]), np.asanyarray(X[~msk]), np.asanyarray(Y[msk]), np.asanyarray(Y[~msk])


# Fit the model
clf = linear_model.LinearRegression()
clf.fit (train_x.astype(np.float32), train_y.astype(np.float32))


# Prediction and the error estimation
test_y_hat = clf.predict(test_x)



# The coefficients
display('Coefficients: ', clf.coef_)
display('Intercept: ',clf.intercept_)
display("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
display("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
display("R2-score: %.2f" % r2_score(test_y_hat , test_y) )

# %% [markdown]
# <h2 id="multiple_regression">Multiple Regression Model</h2>

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline
import os, seaborn as sns

# Get data
os.chdir("C:\\Users\\manka\\Documents\\GitHub\\Machine-learning-quickbook")
df = pd.read_csv("FuelConsumptionCo2.csv")
# df.hist()

# Describe independent and dependent variables
ind = ['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB']
dep = ['CO2EMISSIONS']


# Train test split with proportion split
msk = np.random.rand(len(df)) < 0.8
X, Y = df[ind], df[dep]
# display(X.head)
# display(Y.head)

# plot distributions 
display(sns.pairplot(df[ind+dep]))
plt.show()

# train test split
train_x, test_x, train_y, test_y = np.asanyarray(X[msk]), np.asanyarray(X[~msk]), np.asanyarray(Y[msk]), np.asanyarray(Y[~msk])


# Fit the model
clf = linear_model.LinearRegression()
clf.fit (train_x.astype(np.float32), train_y.astype(np.float32))


# Prediction and the error estimation
test_y_hat = clf.predict(test_x)



# The coefficients
display('Coefficients: ', clf.coef_)
display('Intercept: ',clf.intercept_)
display("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
display("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
display("R2-score: %.2f" % r2_score(test_y_hat , test_y) )

# %% [markdown]
# <h2 id="Polynomial_regression">Polynomial Regression Model</h2>

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
# %matplotlib inline
import os, seaborn as sns

# Get data
os.chdir("C:\\Users\\manka\\Documents\\GitHub\\Machine-learning-quickbook")
df = pd.read_csv("FuelConsumptionCo2.csv")
# df.hist()

# Describe independent and dependent variables
ind = ['ENGINESIZE']
dep = ['CO2EMISSIONS']


# Train test split with proportion split
msk = np.random.rand(len(df)) < 0.8
X, Y = df[ind], df[dep]
# display(X.head)
# display(Y.head)

# plot distributions 
display(sns.pairplot(df[ind+dep]))
plt.show()

# train test split
train_x, test_x, train_y, test_y = np.asanyarray(X[msk]), np.asanyarray(X[~msk]), np.asanyarray(Y[msk]), np.asanyarray(Y[~msk])


# Polynomial transformation
poly = PolynomialFeatures(degree=2)
train_x = poly.fit_transform(train_x)

# Fit the model
clf = linear_model.LinearRegression()
clf.fit (train_x.astype(np.float32), train_y.astype(np.float32))


# Prediction and the error estimation on the transformed test polynomial data
test_x_poly = poly.fit_transform(test_x)
test_y_hat = clf.predict(test_x_poly)



# The coefficients
display('Coefficients: ', clf.coef_)
display('Intercept: ',clf.intercept_)
display("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
display("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
display("R2-score: %.2f" % r2_score(test_y_hat , test_y) )

# %% [markdown]
# <h2 id="Nonlinear_regression">Nonlinear Regression Model - polynomial regressor</h2>

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


import matplotlib.pyplot as plt
import pandas as pd
from pandas_profiling import ProfileReport

import pylab as pl
import numpy as np
# %matplotlib inline
import os, seaborn as sns

# Get data
os.chdir("C:\\Users\\manka\\Documents\\GitHub\\Machine-learning-quickbook")
df = pd.read_csv("china_gdp.csv")

# Data profiling 
print('conducting data profiling')
histogram = df.hist()
plt.show()

# profile = ProfileReport(df)
# profile.to_widgets()

# Analysis
print('conducting analysis')
ind = ['Year']
dep = ['Value']

# plot distributions 
display(sns.pairplot(df[ind+dep]))
plt.show()

# Train test split with proportion split
X, Y = df[ind].values, df[dep].values
train_x, test_x, train_y, test_y = train_test_split( X, Y, test_size=0.2, random_state=4)


model_1 = make_pipeline(PolynomialFeatures(degree = 3),LinearRegression())
model_1.fit(train_x.reshape(-1,1).astype(np.float32),train_y)

# predict
test_y_hat = model_1.predict(test_x)

# Evaluate
print("Polynomial model evaluation")
print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_hat , test_y) )


plt.figure(figsize = (8,5))
plt.scatter(train_x, train_y, alpha = .3, label = 'Data')
plt.plot(train_x, model_1.predict(train_x.reshape(-1,1)), color = 'red', label = 'Model')
plt.plot(test_x, model_1.predict(test_x.reshape(-1,1)), color = 'blue', label = 'Model')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %% [markdown]
# <h2 id="Nonlinear_regression">Nonlinear Regression Model - Decsiton tree</h2>

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

import matplotlib.pyplot as plt
import pandas as pd
from pandas_profiling import ProfileReport

import pylab as pl
import numpy as np
# %matplotlib inline
import os, seaborn as sns

# Get data
os.chdir("C:\\Users\\manka\\Documents\\GitHub\\Machine-learning-quickbook")
df = pd.read_csv("china_gdp.csv")

# Data profiling 
print('conducting data profiling')
histogram = df.hist()
plt.show()

# profile = ProfileReport(df)
# profile.to_widgets()

# Analysis
print('conducting analysis')
ind = ['Year']
dep = ['Value']

# plot distributions 
display(sns.pairplot(df[ind+dep]))
plt.show()

#decisiontree regressor 
model_2 = DecisionTreeRegressor(max_depth = 3)
model_2.fit(train_x.reshape(-1,1).astype(np.float32),train_y)
test_y_hat = model_1.predict(test_x)

# predict
test_y_hat = model_2.predict(test_x)

# Evaluate
print("Decision-tree model evaluation")
print("Mean absolute error: %.2f" % np.mean(np.absolute(test_y_hat - test_y)))
print("Residual sum of squares (MSE): %.2f" % np.mean((test_y_hat - test_y) ** 2))
print("R2-score: %.2f" % r2_score(test_y_hat , test_y) )

plt.figure(figsize = (8,5))
plt.scatter(train_x, train_y, alpha = .3, label = 'Data')
plt.plot(train_x, model_2.predict(train_x.reshape(-1,1)), color = 'red', label = 'Model')
plt.plot(test_x, model_2.predict(test_x.reshape(-1,1)), color = 'blue', label = 'Model')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()


# Linear interpolation model
# from scipy import interpolate
# tck = interpolate.splrep(train_x, train_y, k=1, s=1, t = [35])
# plt.plot(x,interpolate.splev(train_x, tck, der=0), color = 'red', label = 'Model')

# %% [raw]
# # recall is from the reality
# How many True positive from the real positive (True positive + False negative)
#
# #Precision is from what test recorded as positive
# How many True positive from the test positive (True positive + False positive )
#
# # F1 score is the harmonic mean of the Precision and Recall
# F1 = 2 * precision * recall / (precision + recall)
# F1 score for each class needs to be calculated separately
#
#
# # Log loss is the measure of accuracy when the model output is the probability (like in logistic regression)
# y * log(y_hat) + (1-y) * log(1-y_hat)
# sum for each row of the test ( Log loss for True label + log loss for false label ) = total log loss

# %% [markdown]
# <h2 id="Nonlinear_regression">Nonlinear Regression Model - K nearest neighbors</h2>

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LinearRegression
from matplotlib.ticker import NullFormatter
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

import matplotlib.pyplot as plt
import pandas as pd
from pandas_profiling import ProfileReport

import pylab as pl
import numpy as np
# %matplotlib inline
import os, seaborn as sns

# Get data
os.chdir("C:\\Users\\manka\\Documents\\GitHub\\Machine-learning-quickbook")
df = pd.read_csv("teleCust1000t.csv")
# df.hist()

# profile = ProfileReport(df)
# profile.to_widgets()

ind = ['region', 'tenure', 'age', 'marital', 'address', 'income', 'ed', 'employ', 'retire', 'gender', 'reside']
dep = ['custcat']

# plot distributions 
display(sns.pairplot(df[ind+dep]))
plt.show()

# Train test split with proportion split
X, Y = df[ind].values, df[dep].values
train_x, test_x, train_y, test_y = train_test_split( X, Y, test_size=0.2, random_state=4)


# Testing with a random value of K
k = 5
model = KNeighborsClassifier(n_neighbors = k).fit(train_x, train_y)

# Predict 
train_y_hat = model.predict(train_x)
test_y_hat = model.predict(test_x)
  
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(train_y, train_y_hat))
print("Test set Accuracy: ", metrics.accuracy_score(test_y, test_y_hat))

# Finding the best K

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.linear_model import LinearRegression
from matplotlib.ticker import NullFormatter
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

import matplotlib.pyplot as plt
import pandas as pd
from pandas_profiling import ProfileReport

import pylab as pl
import numpy as np
# %matplotlib inline
import os, seaborn as sns

# Get data
os.chdir("C:\\Users\\manka\\Documents\\GitHub\\Machine-learning-quickbook")
df = pd.read_csv("teleCust1000t.csv")

# profile = ProfileReport(df)
# profile.to_widgets()

ind = ['region', 'tenure', 'age', 'marital', 'address', 'income', 'ed', 'employ', 'retire', 'gender', 'reside']
dep = ['custcat']

# plot distributions 
display(sns.pairplot(df[ind+dep], kind = 'hist'))
plt.show()

# Train test split with proportion split
X, Y = df[ind].values, df[dep].values.ravel()
train_x, test_x, train_y, test_y = train_test_split( X, Y, test_size=0.2, random_state=4)

# Find best K to get stats on nearest neighbors
def bestK(maxk = 25, data = df):
    train_x, test_x, train_y, test_y = train_test_split( X, Y, test_size=0.2, random_state=4)
    # Finding the best K    
    k = []
    K = maxk
    mean_accuracy = np.zeros((K-1))
    std_accuracy = np.zeros((K-1))
    for k in range(1,K):  
        model = KNeighborsClassifier(n_neighbors = k).fit(train_x, train_y)
        test_y_hat = model.predict(test_x)    
        mean_accuracy[k-1] = metrics.accuracy_score(test_y, test_y_hat)
        std_accuracy[k-1] = np.std(test_y_hat==test_y)/np.sqrt(test_y_hat.shape[0])
    plt.plot(range(1,K), mean_accuracy,'g')
    plt.fill_between(x = range(1,K), \
                     y1 = mean_accuracy - 1 * std_accuracy, \
                     y2 = mean_accuracy + 1 * std_accuracy, \
                     alpha=0.10)
    plt.legend(('Accuracy ', '+/- 1 std deviation'))
    plt.ylabel('Accuracy ')
    plt.xlabel('Number of Neighbors (K)')
    plt.tight_layout()
    plt.show()
    return(np.argmax(mean_accuracy, axis=0))


# Using the best K to answer 
k = bestK(maxk=250, data=df)
model = KNeighborsClassifier(n_neighbors = k).fit(train_x, train_y)

# Predict 
train_y_hat = model.predict(train_x)
test_y_hat = model.predict(test_x)
  
from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(train_y, train_y_hat))
print("Test set Accuracy: ", metrics.accuracy_score(test_y, test_y_hat))
# Out:
# Train set Accuracy:  0.38125
# Test set Accuracy:  0.395
